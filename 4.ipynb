# %% [markdown]
# #Корреляция и регрессия
# ##Шаихов Халил Ильясович ПИ-323
# ###№Зк 19130163

# %% [markdown]
# Генерация исходных данных

# %%
import numpy as np
np.random. seed(19130163)
N = 100

# %% [markdown]
# Равномерное распределение

# %%
x = np.random.uniform(low=150, high=200, size=N)
np.random.uniform?

# %% [markdown]
# Нормальное распределение

# %%
np. random. seed(36103191)
e = np.random.normal(loc=0, scale=10, size=N)
np.random.normal?

# %% [markdown]
# Прямая линия + разброс

# %%
y = -100 + x + e

# %% [markdown]
# Диаграмма рассеивания

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.title("Диагармма рассеивания")
plt.xlabel("X")
plt.ylabel("Y")
plt. scatter(x, y)
plt. show()

# %% [markdown]
# Корреляционный анализ

# %%
import scipy.stats as st
r = st.pearsonr(x, y)[0]
rho = st.spearmanr(x, y)[0]
tau = st.kendalltau(x, y)[0]
print(f"Коэффициент линейной корреляции Пирсона: \t{r:.3f}")
print(f"Коэффициент корреляции рангов Спирмена: \t{rho:.3f}")
print(f"Коэффициент корреляции рангов Кендалла: \t{tau:.3f}")
# Out:
# Коэффициент линейной корреляции Пирсона: 	0.841
# Коэффициент корреляции рангов Спирмена: 	0.843
# Коэффициент корреляции рангов Кендалла: 	0.657

# %% [markdown]
# Регрессионный анализ

# %%
results_yx = st.linregress(x, y)
a = results_yx.intercept
b = results_yx.slope
print(f"a={a:.3f}")
print(f"b={b:.3f}")
# Out:
# a=-112.048
# b=1.081

# %% [markdown]
# Проверка

# %%
plt.figure(figsize=(10,10))
plt.title("Диагармма рассеивания")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x, y)
x_yx = np.array([150, 200])
y_yx=a+b*x_yx
plt.plot(x_yx, y_yx, 'r-')
plt.show()

# %% [markdown]
# Регрессия y=f(x)

# %%
results_xy = st.linregress(y, x)
c = results_xy.intercept
d = results_xy.slope
c, d
# Out:
# (124.49325111359882, 0.6537568318358591)

# %% [markdown]
# Пересечение линий регрессии

# %%
x_mean = np.mean(x)
y_mean = np. mean(y)
x_mean, y_mean
# Out:
# (174.5883724793122, 76.62653593238615)

# %% [markdown]
# Диаграмма рассеивания + линии регресcии + пересечение

# %%
plt.figure(figsize=(8,8))
plt.title("Диагармма рассеивания")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x, y, c='grey', label = 'исходные данные')

x_yx = np.array([150, 200])
y_yx=a+b*x_yx
plt.plot(x_yx, y_yx, 'g' , label = 'линия регрессии y(x)')

x_yx=c+d*y_yx
plt.plot(x_yx, y_yx, 'y' , label = 'линия регрессии x(y)')

plt.plot(x_mean, y_mean, 'o-r', label = 'среднее значение')
#plt.plot( 'y' , label = 'линия регрессии y(x)')
plt.legend(fontsize=10, loc=0)
plt.show()
