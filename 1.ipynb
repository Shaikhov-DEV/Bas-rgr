# %% [markdown]
# # Греческий алфавит
# Заглавная|Строчная|Название
# --|--|--
# A|α|альфа
# B|β|бета
# Г|γ|гамма
# Δ|δ|дельта
# E|ε|эпсилон
# Z|ζ|дзета
# H|η|эта
# Θ|θ|тета
# I|ί|йота
# K|κ|каппа
# Λ|λ|ламбда
# M|μ|мю
# N|𝜈|ню
# Ξ|ξ|кси
# O|o|омикрон
# П|π|пи
# Ρ|ρ|ро
# Σ|σ|сигма
# Τ|τ|тау
# υ|υ|ипсилон
# Φ|𝝋|фи
# Х|χ|хи
# Ψ|ψ|пси
# Ω|ω|омега
